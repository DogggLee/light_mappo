# %%
import numpy as np
import math

a = np.array([0., 1.])
b = np.array([1., 0.])

cross = a[0] * b[1] - b[0]*a[1]
dot = np.dot(a, b)   

rel = np.arctan2(cross, dot)
# Out:
# /tmp/ipykernel_2849115/1431123605.py:7: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   cross = np.cross(a, b)
